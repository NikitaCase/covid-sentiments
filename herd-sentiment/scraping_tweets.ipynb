# %%
import twint 
import nest_asyncio
nest_asyncio.apply()

# %%
def Scrape_Tweets(location, filename):
    c = twint.Config()
    c.Since='2020-12-1'
    c.Until='2020-12-06'
    c.Near= location    
    c.Search='covid vaccine'
    c.Store_csv = True
    c.Output = filename
    
    twint.run.Search(c)

# %%
Scrape_Tweets('Vancouver', 'raw_covvac_vancouver.csv')
# Out:
# 1334821446988623872 2020-12-04 06:26:47 -0500 <euglena_x> istg when the covid vaccine comes, it’s going to be an issue about whether or not to take it 😶
# 1334626784986316800 2020-12-03 17:33:16 -0500 <oconnor322> @steeletalk @JATetro @CKNW What if a person already had a presumed case of COVID-19 early on, but with no antibody test to confirm early exposure. Would that person already be "self-vaccinated" from the e posture or would they also need the vaccine?
# 1334611151519248385 2020-12-03 16:31:09 -0500 <notionport> Nice from @SeanSilcoff: Inside Acuitas Therapeutics, the Vancouver company providing a crucial piece of Pfizer’s COVID-19 vaccine
# 1334540798830891008 2020-12-03 11:51:35 -0500 <tedfujimoto> If you are on the fence or opposed to taking the vaccine, would this change your mind? #COVIDー19 #CovidVaccine #vaccines
# ...

# %%
Scrape_Tweets('Montreal','raw_covvac_montreal.csv')
# Out:
# 1334751454305906689 2020-12-04 01:48:39 -0500 <freddymckay89> I wish pharmaceutical company would put as much energy in a cancer cure or Alzheimer or other illness as they did for the covid vaccine.
# 1334711016953942016 2020-12-03 23:07:58 -0500 <Lilianamaguti> First COVID-19 vaccine could be delivered to distribution points as early as end of December, Fortin says  https://t.co/JBSOZmm8Op
# 1334241315882553344 2020-12-02 16:01:33 -0500 <mtlblog> 65 People In Quebec Will Be Among The First To Get A Trial COVID-19 Vaccine  https://t.co/OwQotFrAfE #News #Montreal
# 1334166832417300480 2020-12-02 11:05:35 -0500 <dancarnelly> So the EU needs agreement from 27 member states pushing its decision to the end of year/early 2021, making them look a little bad. Independence has its privileges after all.  EU criticises 'hasty' UK approval of COVID-19 vaccine | Article [AMP] | Reuters  https://t.co/gaEDRtMUXx
# ...

# %%
c = twint.Config()
c.Since='2020-12-01'
c.Near= 'Montreal'   
c.Search='covid vaccine'
c.Store_csv = True
c.Output = 'montreal.csv'
    
twint.run.Search(c)
# Out:
# 1367506459966193671 2021-03-04 11:05:21 -0500 <sibomanaxyz987> Indian Prime Minister Narendra Modi is administered a COVID-19 vaccine in New Delhi, India, March 1, 2021. India is expanding its COVID-19 vaccination drive beyond health care and front-line workers... (Photo by Prime Minister of India Narendra Modi's twitter handle via AP Photo)  https://t.co/NwbZ9TAcEc
# 1367505408064167941 2021-03-04 11:01:10 -0500 <sibomanaxyz987> A frontline worker reacts as she receives a dose of AstraZeneca's COVISHIELD vaccine, produced by the Serum Institute of India, during COVID-19 vaccination campaign at a medical centre in New Delhi, India, February 24, 2021. (Photo by Anushree Fadnavis/Reuters)  https://t.co/awPy0mlijX
# ...

# %%
import pandas as pd

# %%
vc1 = pd.read_csv('raw_covvac_montreal.csv')
vc2 = pd.read_csv('montreal.csv')
#vc3 = pd.read_csv('mo_file.csv')

vc2.head()
# Out:
#                     id      conversation_id  \
# 0  1334751454305906689  1334751454305906689
# 1  1334711016953942016  1334711016953942016
# 2  1334333822058500105  1334333822058500105
# 3  1334302822658166785  1334241788341653514
# 4  1334241315882553344  1334241315882553344
#
#                                   created_at        date      time  timezone  \
# 0  2020-12-04 01:48:39 Eastern Standard Time  2020-12-04  01:48:39      -500
# 1  2020-12-03 23:07:58 Eastern Standard Time  2020-12-03  23:07:58      -500
# 2  2020-12-02 22:09:08 Eastern Standard Time  2020-12-02  22:09:08      -500
# 3  2020-12-02 20:05:57 Eastern Standard Time  2020-12-02  20:05:57      -500
# 4  2020-12-02 16:01:33 Eastern Standard Time  2020-12-02  16:01:33      -500
#
#       user_id       username                 name  \
# 0   724243674  freddymckay89  Freddy McKay [SDMN]
# 1  2292958556  lilianamaguti    Liliana Gutierrez
# 2  1027677408  commentor2013   André C. Gauthier🌈
# ...

# %%
# twint -s "covid vaccine" --near Montreal --since 2020-09-12 --until 2020-10-12 -o mofile.csv 
c = twint.Config()
c.Since='2020-12-01'
c.until ='2021-01-01'
c.Near= 'Montreal'   
c.Search='covid vaccine'
c.Store_csv = True
c.Output = 'mo_file2.csv'
    
twint.run.Search(c)
# Out:
# 1367555056371961859 2021-03-04 14:18:28 -0500 <legalnomads> An orangutan named Karen, the first in the world to have open-heart surgery in 1994, has made medical history again: She’s among the first great apes to get a COVID-19 vaccine, one built specifically for animals:  https://t.co/s0SkClcCBA (by @natashaldaly)
# 1367550071093477377 2021-03-04 13:58:39 -0500 <ElleMoss458> @ProjectLincoln @H_Combs The vaccine doesn’t stop you from getting covid so doesn’t really make a difference if 93% of Texans haven’t been vaccinated no???🤷🏻‍♀️
# 1367548900035411976 2021-03-04 13:54:00 -0500 <CityNewsMTL> Who have provinces pegged to receive COVID-19 vaccines in the coming weeks?  https://t.co/EwtTiZzpsY
# 1367545743419015171 2021-03-04 13:41:27 -0500 <chanelapalooza> If anyone needs help booking COVID vaccine appointments for their family: call me!! I booked 9 appointments in the first 4 days. I am a ClicSanté expert. 👵🏼💉💅🏼
# ...

# %%
mo2 = pd.read_csv('mo_file2.csv')
mo2.shape
# Out:
# (685, 36)

# %%
mo1 = pd.read_csv('raw_covvac_montreal.csv')
mo3 = pd.read_csv('montreal.csv')

# %%
mont = mo1.append(mo2)

# %%
mont = mont.append(mo3)

# %%
mont.shape
# Out:
# (1382, 36)

# %%
mont = mont.drop_duplicates(subset='id')
mont.shape
# Out:
# (705, 36)

# %%
mont.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
montr = mont[['id', 'conversation_id', 'date','user_id', 
              'username', 'tweet', 'language','replies_count', 
              'retweets_count', 'likes_count','retweet', 'near', 'geo']]
montr.head()
# Out:
#                     id      conversation_id        date     user_id  \
# 0  1334751454305906689  1334751454305906689  2020-12-04   724243674
# 1  1334711016953942016  1334711016953942016  2020-12-03  2292958556
# 2  1334241315882553344  1334241315882553344  2020-12-02   811533451
# 3  1334166832417300480  1334166832417300480  2020-12-02   189812607
# 4  1334102707259502594  1334102204635115521  2020-12-02    56837610
#
#         username                                              tweet language  \
# 0  freddymckay89  I wish pharmaceutical company would put as muc...       en
# 1  lilianamaguti  First COVID-19 vaccine could be delivered to d...       en
# 2        mtlblog  65 People In Quebec Will Be Among The First To...       en
# 3    dancarnelly  So the EU needs agreement from 27 member state...       en
# 4        enamhto  “It is essential that law enforcement is as pr...       en
#
#    replies_count  retweets_count  likes_count  retweet      near  geo
# ...
